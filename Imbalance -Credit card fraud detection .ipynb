# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
dfcard = pd.read_csv(r"C:\Users\Saniya Mirza\Desktop\Pandas\Credit card Fraud detection.csv")

# %%
dfcard
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 1            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 2            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 3            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# 4            2.0  -0.425966   0.960523  1.141109 -0.168252  0.420987
# ...          ...        ...        ...       ...       ...       ...
# 284801  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284802  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284803  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284804  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284805  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dfcard.shape
# Out:
# (284806, 31)

# %%
dfcard["Class"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284801    0
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# Name: Class, Length: 284806, dtype: int64

# %%
dfcard.drop("Class",axis = 1)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 1            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 2            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 3            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# 4            2.0  -0.425966   0.960523  1.141109 -0.168252  0.420987
# ...          ...        ...        ...       ...       ...       ...
# 284801  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284802  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284803  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284804  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284805  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
x = dfcard.drop("Class",axis = 1)

# %%
x
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 1            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 2            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 3            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# 4            2.0  -0.425966   0.960523  1.141109 -0.168252  0.420987
# ...          ...        ...        ...       ...       ...       ...
# 284801  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284802  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284803  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284804  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284805  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y = dfcard["Class"]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284801    0
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# Name: Class, Length: 284806, dtype: int64

# %% [markdown]
# ### Imbalance

# %%
y.value_counts()
# Out:
# Class
# 0    284314
# 1       492
# Name: count, dtype: int64

# %%
y.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Class'>

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler()

# %%
ros
# Out:
# RandomOverSampler()

# %%
x_ros,y_ros = ros.fit_resample(x,y)

# %%
x.shape
# Out:
# (284806, 30)

# %%
y.shape
# Out:
# (284806,)

# %%
y.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Class'>

# %%
y_ros.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Class'>

# %% [markdown]
# ### Method - 2 SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
smt = SMOTE()

# %%
smt
# Out:
# SMOTE()

# %%
x_smt,y_smt = smt.fit_resample(x,y)

# %%
x.shape , x_smt.shape
# Out:
# ((284806, 30), (568628, 30))

# %%
y.shape , y_smt.shape
# Out:
# ((284806,), (568628,))

# %%
y.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Class'>

# %%
y_smt.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Class'>

# %% [markdown]
# ### Undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler()

# %%
rus
# Out:
# RandomUnderSampler()

# %%
x_rus,y_rus = rus.fit_resample(x,y)

# %%
x.shape
# Out:
# (284806, 30)

# %%
x_rus.shape
# Out:
# (984, 30)

# %%
y.shape
# Out:
# (284806,)

# %%
y_rus.shape
# Out:
# (984,)

# %%
y.value_counts()
# Out:
# Class
# 0    284314
# 1       492
# Name: count, dtype: int64

# %%
y_rus.value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
y.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Class'>

# %%
y_rus.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Class'>

# %% [markdown]
# ### Undersampling without any Imblearn Methods

# %%
dfcard
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 1            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 2            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 3            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# 4            2.0  -0.425966   0.960523  1.141109 -0.168252  0.420987
# ...          ...        ...        ...       ...       ...       ...
# 284801  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284802  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284803  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284804  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284805  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dfcard["Class"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
dfcard["Class"] == 0
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 284801    True
# 284802    True
# 284803    True
# 284804    True
# 284805    True
# Name: Class, Length: 284806, dtype: bool

# %%
dfcard[dfcard["Class"] == 0]
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 1            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 2            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 3            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# 4            2.0  -0.425966   0.960523  1.141109 -0.168252  0.420987
# ...          ...        ...        ...       ...       ...       ...
# 284801  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284802  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284803  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284804  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284805  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dfzero = dfcard[dfcard["Class"] == 0]

# %%
dfzero
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 1            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 2            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 3            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# 4            2.0  -0.425966   0.960523  1.141109 -0.168252  0.420987
# ...          ...        ...        ...       ...       ...       ...
# 284801  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284802  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284803  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284804  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284805  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dfcard["Class"] == 1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284801    False
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# Name: Class, Length: 284806, dtype: bool

# %%
dfcard[dfcard["Class"] == 1]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 540        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 622        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4919      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6107      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6328      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279862  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280142  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280148  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281143  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281673  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
dfone = dfcard[dfcard["Class"] == 1]

# %%
dfone
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 540        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 622        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4919      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6107      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6328      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279862  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280142  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280148  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281143  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281673  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
dfzero.shape
# Out:
# (284314, 31)

# %%
dfzero = dfzero.sample(492)

# %%
dfzero
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 220301  142109.0  1.808668 -1.197522 -2.291089 -0.690236 -0.312654 -1.756994
# 41935    40890.0 -0.806317  0.496919  2.362844  1.051459 -0.231735  0.720844
# 220024  141988.0 -0.439490  0.389228  0.209763 -0.483860  0.603277 -1.230838
# 170834  120375.0  1.711917 -1.493441 -1.153384 -0.586388 -1.009113 -1.036921
# 77718    57179.0  1.227177 -1.409543  0.572864 -1.223336 -1.821991 -0.862197
# ...          ...       ...       ...       ...       ...       ...       ...
# 282123  170672.0 -0.820562  0.179116  1.939736 -1.740858 -0.334079 -0.523195
# 178452  123631.0 -1.968574 -3.322043  0.007347 -2.374015  2.248239 -1.866346
# 110800   71980.0  1.196770 -0.047906  0.472539  0.757095 -0.275168  0.105900
# 277004  167399.0 -0.286556  0.708188 -0.390301 -0.569652  1.108397 -0.618728
# 216951  140702.0 -0.110826  0.971289  0.193929 -0.376408  0.634071 -1.015009
#
# ...

# %%
pd.concat([dfzero,dfone])
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 220301  142109.0  1.808668 -1.197522 -2.291089 -0.690236 -0.312654 -1.756994
# 41935    40890.0 -0.806317  0.496919  2.362844  1.051459 -0.231735  0.720844
# 220024  141988.0 -0.439490  0.389228  0.209763 -0.483860  0.603277 -1.230838
# 170834  120375.0  1.711917 -1.493441 -1.153384 -0.586388 -1.009113 -1.036921
# 77718    57179.0  1.227177 -1.409543  0.572864 -1.223336 -1.821991 -0.862197
# ...          ...       ...       ...       ...       ...       ...       ...
# 279862  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280142  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280148  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281143  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281673  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
dfrus = pd.concat([dfzero,dfone])

# %%
dfrus
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 220301  142109.0  1.808668 -1.197522 -2.291089 -0.690236 -0.312654 -1.756994
# 41935    40890.0 -0.806317  0.496919  2.362844  1.051459 -0.231735  0.720844
# 220024  141988.0 -0.439490  0.389228  0.209763 -0.483860  0.603277 -1.230838
# 170834  120375.0  1.711917 -1.493441 -1.153384 -0.586388 -1.009113 -1.036921
# 77718    57179.0  1.227177 -1.409543  0.572864 -1.223336 -1.821991 -0.862197
# ...          ...       ...       ...       ...       ...       ...       ...
# 279862  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280142  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280148  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281143  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281673  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...
